# %%
# %run "/Workspace/Users/pjadhav564@gmail.com/Brazil_project/functions"

# %%
bronze_path = "/Volumes/e_commerce_brazil/e_com_bronze/bronze_clean" 
silver_path = "/Volumes/e_commerce_brazil/e_com_silver/updated_silver"



#Orders table list find
df = read_csv(f"{bronze_path}/orders")
df =df.dropDuplicates(["order_status"]).select("order_status")
df.display()

# %%
# products table column names

df = readfile(f"{bronze_path}/products")
df = print(df.columns)

# %%
# seller table column names list
bronze_path = "/Volumes/prod_retail/bronze_raw/checkpoints/"

df = readfile(f"{bronze_path}/sellers")
df = print(df.columns)

# %%
# for dimension table, print column names
silver_path = "/Volumes/prod_retail/silver_clean/checkpoints/"
df = readfile(f"{silver_path}/customer")
df = print(df.columns)
df = readfile(f"{silver_path}/products")
df = print(df.columns)
df = readfile(f"{silver_path}/category_translation")
df = print(df.columns)
