# %%
# %run "/Workspace/Users/pjadhav564@gmail.com/Brazil_project/functions"

# %% [markdown]
# ## BRONZE LAYER – RAW INGESTION

# %%
fileset = {
    "customers":"/Volumes/e_commerce_brazil/landing_raw/raw_data_001/DATA/olist_customers_dataset.csv",
    "orders":"/Volumes/e_commerce_brazil/landing_raw/raw_data_001/DATA/olist_orders_dataset.csv",
    "order_items":"/Volumes/e_commerce_brazil/landing_raw/raw_data_001/DATA/olist_order_items_dataset.csv",
    "order_payments":"/Volumes/e_commerce_brazil/landing_raw/raw_data_001/DATA/olist_order_payments_dataset.csv",
    "order_reviews":"/Volumes/e_commerce_brazil/landing_raw/raw_data_001/DATA/olist_order_reviews_dataset.csv",
    "products":"/Volumes/e_commerce_brazil/landing_raw/raw_data_001/DATA/olist_products_dataset.csv",
    "sellers":"/Volumes/e_commerce_brazil/landing_raw/raw_data_001/DATA/olist_sellers_dataset.csv",
    "geolocation":"/Volumes/e_commerce_brazil/landing_raw/raw_data_001/DATA/olist_geolocation_dataset.csv"
}

#ingest timestamp to all
for i, path in fileset.items():
    raw_df= read_csv(path)
    bronze_df = ingest_ts(raw_df)
    new_path= f"/Volumes/e_commerce_brazil/e_com_bronze/bronze_clean/{i}"
    writefile(bronze_df.coalesce(1),new_path,mode="append")
    display(bronze_df)
